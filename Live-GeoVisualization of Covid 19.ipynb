# %%
import json
import folium
import requests
import mimetypes
import http.client
import pandas as pd
from folium.plugins import HeatMap
from pandas.io.json import json_normalize

# %% [markdown]
# ### Accessing Data from API

# %%
conn = http.client.HTTPSConnection("api.covid19api.com")
payload = ''
headers = {}
conn.request("GET", "/summary", payload, headers)
res = conn.getresponse()
data = res.read().decode('UTF-8')

# %% [markdown]
# ### Coverting received data to JSON

# %%
covid1= json.loads(data)
covid1
# Out:
# {'ID': 'a1dd6a90-c5a7-40c3-905d-fadd470ce973',
#  'Message': '',
#  'Global': {'NewConfirmed': 371561,
#   'TotalConfirmed': 186379833,
#   'NewDeaths': 6523,
#   'TotalDeaths': 4026120,
#   'NewRecovered': 401088,
#   'TotalRecovered': 123003497,
#   'Date': '2021-07-12T04:09:49.631Z'},
#  'Countries': [{'ID': '5c1da4d5-84d6-46bb-a883-d351e5348249',
#    'Country': 'Afghanistan',
#    'CountryCode': 'AF',
#    'Slug': 'afghanistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 131586,
#    'NewDeaths': 0,
#    'TotalDeaths': 5561,
#    'NewRecovered': 851,
#    'TotalRecovered': 81077,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '2e99b380-2887-4f55-bb12-0b029ed7e9a5',
#    'Country': 'Albania',
#    'CountryCode': 'AL',
#    'Slug': 'albania',
#    'NewConfirmed': 5,
#    'TotalConfirmed': 132592,
#    'NewDeaths': 0,
#    'TotalDeaths': 2456,
#    'NewRecovered': 3,
#    'TotalRecovered': 130050,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '2a76ca19-d8db-43b9-b7f7-90c8da735df1',
#    'Country': 'Algeria',
#    'CountryCode': 'DZ',
#    'Slug': 'algeria',
#    'NewConfirmed': 768,
#    'TotalConfirmed': 146064,
#    'NewDeaths': 12,
#    'TotalDeaths': 3836,
#    'NewRecovered': 519,
#    'TotalRecovered': 101430,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'a70ef799-d1c6-4f45-9db3-744821919fbc',
#    'Country': 'Andorra',
#    'CountryCode': 'AD',
#    'Slug': 'andorra',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 14075,
#    'NewDeaths': 0,
#    'TotalDeaths': 127,
#    'NewRecovered': 0,
#    'TotalRecovered': 13770,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'ebccbf43-269d-4f07-b5bc-7c55bada024d',
#    'Country': 'Angola',
#    'CountryCode': 'AO',
#    'Slug': 'angola',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 39881,
#    'NewDeaths': 0,
#    'TotalDeaths': 929,
#    'NewRecovered': 0,
#    'TotalRecovered': 34298,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'a609eee5-7315-4535-9e1f-8f73e2164cf0',
#    'Country': 'Antigua and Barbuda',
#    'CountryCode': 'AG',
#    'Slug': 'antigua-and-barbuda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1266,
#    'NewDeaths': 0,
#    'TotalDeaths': 42,
#    'NewRecovered': 0,
#    'TotalRecovered': 1222,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'ccfd8f67-b3fe-4243-b4c9-5c4178e99d95',
#    'Country': 'Argentina',
#    'CountryCode': 'AR',
#    'Slug': 'argentina',
#    'NewConfirmed': 8850,
#    'TotalConfirmed': 4647948,
#    'NewDeaths': 280,
#    'TotalDeaths': 98781,
#    'NewRecovered': 17967,
#    'TotalRecovered': 4282904,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '63395718-eec6-4a83-a339-a72a42a3169a',
#    'Country': 'Armenia',
#    'CountryCode': 'AM',
#    'Slug': 'armenia',
#    'NewConfirmed': 103,
#    'TotalConfirmed': 226388,
#    'NewDeaths': 2,
#    'TotalDeaths': 4544,
#    'NewRecovered': 71,
#    'TotalRecovered': 217658,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'f86b28a6-dfcc-42f7-8f87-6ca7f226ccf7',
#    'Country': 'Australia',
#    'CountryCode': 'AU',
#    'Slug': 'australia',
#    'NewConfirmed': 85,
#    'TotalConfirmed': 31100,
#    'NewDeaths': 1,
#    'TotalDeaths': 911,
#    'NewRecovered': 6,
#    'TotalRecovered': 23858,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'cd5f3e12-49c6-452a-a2c8-1a385b53aed2',
#    'Country': 'Austria',
#    'CountryCode': 'AT',
#    'Slug': 'austria',
#    'NewConfirmed': 159,
#    'TotalConfirmed': 651612,
#    'NewDeaths': 0,
#    'TotalDeaths': 10723,
#    'NewRecovered': 75,
#    'TotalRecovered': 638889,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'ed225373-0583-4c5e-a547-2e7db9448799',
#    'Country': 'Azerbaijan',
#    'CountryCode': 'AZ',
#    'Slug': 'azerbaijan',
#    'NewConfirmed': 156,
#    'TotalConfirmed': 337254,
#    'NewDeaths': 0,
#    'TotalDeaths': 4984,
#    'NewRecovered': 37,
#    'TotalRecovered': 330762,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'ee9fa785-6f56-4eee-8a25-f53a8c0ce594',
#    'Country': 'Bahamas',
#    'CountryCode': 'BS',
#    'Slug': 'bahamas',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 13024,
#    'NewDeaths': 0,
#    'TotalDeaths': 252,
#    'NewRecovered': 0,
#    'TotalRecovered': 11855,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '4007bc04-d292-48c7-bdc0-b2b7e10dab50',
#    'Country': 'Bahrain',
#    'CountryCode': 'BH',
#    'Slug': 'bahrain',
#    'NewConfirmed': 100,
#    'TotalConfirmed': 267212,
#    'NewDeaths': 1,
#    'TotalDeaths': 1377,
#    'NewRecovered': 199,
#    'TotalRecovered': 264687,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'c3d141e5-1876-4f7c-a78c-e28fb8111724',
#    'Country': 'Bangladesh',
#    'CountryCode': 'BD',
#    'Slug': 'bangladesh',
#    'NewConfirmed': 11874,
#    'TotalConfirmed': 1021189,
#    'NewDeaths': 230,
#    'TotalDeaths': 16419,
#    'NewRecovered': 6362,
#    'TotalRecovered': 874501,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'e92f6e9e-20c9-4b00-a038-362b7f28eacc',
#    'Country': 'Barbados',
#    'CountryCode': 'BB',
#    'Slug': 'barbados',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4136,
#    'NewDeaths': 0,
#    'TotalDeaths': 48,
#    'NewRecovered': 0,
#    'TotalRecovered': 4036,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '7e5be855-42e2-4d9e-9ca0-b86c359368e3',
#    'Country': 'Belarus',
#    'CountryCode': 'BY',
#    'Slug': 'belarus',
#    'NewConfirmed': 1020,
#    'TotalConfirmed': 427906,
#    'NewDeaths': 10,
#    'TotalDeaths': 3257,
#    'NewRecovered': 1220,
#    'TotalRecovered': 421305,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'accec42c-2036-4e59-b63e-fbf86493c500',
#    'Country': 'Belgium',
#    'CountryCode': 'BE',
#    'Slug': 'belgium',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1093700,
#    'NewDeaths': 0,
#    'TotalDeaths': 25198,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '3eea3009-7ac2-4729-a45b-6ce828c0beea',
#    'Country': 'Belize',
#    'CountryCode': 'BZ',
#    'Slug': 'belize',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 13518,
#    'NewDeaths': 0,
#    'TotalDeaths': 330,
#    'NewRecovered': 0,
#    'TotalRecovered': 12848,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '5f3e6b7e-1fee-4101-a471-3001186f0322',
#    'Country': 'Benin',
#    'CountryCode': 'BJ',
#    'Slug': 'benin',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8227,
#    'NewDeaths': 0,
#    'TotalDeaths': 105,
#    'NewRecovered': 0,
#    'TotalRecovered': 8000,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'b9292df7-744b-4ad0-a5a1-0b3d0ef66215',
#    'Country': 'Bhutan',
#    'CountryCode': 'BT',
#    'Slug': 'bhutan',
#    'NewConfirmed': 9,
#    'TotalConfirmed': 2275,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 40,
#    'TotalRecovered': 1973,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'bb51f7c4-2311-4b41-a786-1c71a4019280',
#    'Country': 'Bolivia',
#    'CountryCode': 'BO',
#    'Slug': 'bolivia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 453595,
#    'NewDeaths': 0,
#    'TotalDeaths': 17200,
#    'NewRecovered': 0,
#    'TotalRecovered': 378733,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '7824edf4-b91b-42c0-b5fd-0e443f97da04',
#    'Country': 'Bosnia and Herzegovina',
#    'CountryCode': 'BA',
#    'Slug': 'bosnia-and-herzegovina',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 205145,
#    'NewDeaths': 0,
#    'TotalDeaths': 9656,
#    'NewRecovered': 0,
#    'TotalRecovered': 184999,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'd17edab1-92ce-4e6e-b4f7-f640095f37ac',
#    'Country': 'Botswana',
#    'CountryCode': 'BW',
#    'Slug': 'botswana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 75388,
#    'NewDeaths': 0,
#    'TotalDeaths': 1202,
#    'NewRecovered': 0,
#    'TotalRecovered': 69914,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '1525f6c1-a902-415c-9fe3-c06a209c45e4',
#    'Country': 'Brazil',
#    'CountryCode': 'BR',
#    'Slug': 'brazil',
#    'NewConfirmed': 48504,
#    'TotalConfirmed': 19069003,
#    'NewDeaths': 1205,
#    'TotalDeaths': 532893,
#    'NewRecovered': 160032,
#    'TotalRecovered': 16983333,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'b26bdd5e-b1d6-43b0-8156-35f427a72cb8',
#    'Country': 'Brunei Darussalam',
#    'CountryCode': 'BN',
#    'Slug': 'brunei',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 268,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 255,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'c00ca969-f460-46bc-89d1-7bbf4a0cbf6b',
#    'Country': 'Bulgaria',
#    'CountryCode': 'BG',
#    'Slug': 'bulgaria',
#    'NewConfirmed': 16,
#    'TotalConfirmed': 422462,
#    'NewDeaths': 0,
#    'TotalDeaths': 18140,
#    'NewRecovered': 1,
#    'TotalRecovered': 396316,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '902215d6-af05-4d76-bfc9-5b2bcb6e66c0',
#    'Country': 'Burkina Faso',
#    'CountryCode': 'BF',
#    'Slug': 'burkina-faso',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 13509,
#    'NewDeaths': 0,
#    'TotalDeaths': 168,
#    'NewRecovered': 0,
#    'TotalRecovered': 13317,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '389b0209-4a28-493c-aab7-52259a7c81eb',
#    'Country': 'Burundi',
#    'CountryCode': 'BI',
#    'Slug': 'burundi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5608,
#    'NewDeaths': 0,
#    'TotalDeaths': 8,
#    'NewRecovered': 0,
#    'TotalRecovered': 773,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '37a6e7e7-6b1a-4ad1-8701-fd1ba67612be',
#    'Country': 'Cambodia',
#    'CountryCode': 'KH',
#    'Slug': 'cambodia',
#    'NewConfirmed': 981,
#    'TotalConfirmed': 60959,
#    'NewDeaths': 21,
#    'TotalDeaths': 902,
#    'NewRecovered': 815,
#    'TotalRecovered': 52475,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'daa40e32-6b2a-47c3-82be-5d2e83a42b8f',
#    'Country': 'Cameroon',
#    'CountryCode': 'CM',
#    'Slug': 'cameroon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 80858,
#    'NewDeaths': 0,
#    'TotalDeaths': 1324,
#    'NewRecovered': 0,
#    'TotalRecovered': 35261,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '8be2851c-fe66-416a-beb6-c406c08caabc',
#    'Country': 'Canada',
#    'CountryCode': 'CA',
#    'Slug': 'canada',
#    'NewConfirmed': 257,
#    'TotalConfirmed': 1195295,
#    'NewDeaths': 6,
#    'TotalDeaths': 24081,
#    'NewRecovered': 249,
#    'TotalRecovered': 1395951,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'f522f629-3705-4a7d-b873-bc29d64d719c',
#    'Country': 'Cape Verde',
#    'CountryCode': 'CV',
#    'Slug': 'cape-verde',
#    'NewConfirmed': 37,
#    'TotalConfirmed': 33006,
#    'NewDeaths': 0,
#    'TotalDeaths': 289,
#    'NewRecovered': 38,
#    'TotalRecovered': 32179,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '37b093d3-3481-43ab-8fb7-c98454ee3728',
#    'Country': 'Central African Republic',
#    'CountryCode': 'CF',
#    'Slug': 'central-african-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7142,
#    'NewDeaths': 0,
#    'TotalDeaths': 98,
#    'NewRecovered': 0,
#    'TotalRecovered': 6859,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '41f19c26-dbf1-4e13-a544-1b2f9f580bd3',
#    'Country': 'Chad',
#    'CountryCode': 'TD',
#    'Slug': 'chad',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4954,
#    'NewDeaths': 0,
#    'TotalDeaths': 174,
#    'NewRecovered': 0,
#    'TotalRecovered': 4777,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '1dba31de-9da5-468c-aaaa-6666cd099367',
#    'Country': 'Chile',
#    'CountryCode': 'CL',
#    'Slug': 'chile',
#    'NewConfirmed': 2769,
#    'TotalConfirmed': 1585160,
#    'NewDeaths': 131,
#    'TotalDeaths': 33767,
#    'NewRecovered': 2809,
#    'TotalRecovered': 1532078,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '70e9751c-3ac6-4c4c-b794-3224a355fdf6',
#    'Country': 'China',
#    'CountryCode': 'CN',
#    'Slug': 'china',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 104020,
#    'NewDeaths': 0,
#    'TotalDeaths': 4848,
#    'NewRecovered': 4,
#    'TotalRecovered': 98590,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '2dd7e2ed-bdf8-4520-9072-9f4ef6348d8d',
#    'Country': 'Colombia',
#    'CountryCode': 'CO',
#    'Slug': 'colombia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4471622,
#    'NewDeaths': 0,
#    'TotalDeaths': 111731,
#    'NewRecovered': 0,
#    'TotalRecovered': 4199227,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '918f9d64-0250-490e-b424-960fde4bff45',
#    'Country': 'Comoros',
#    'CountryCode': 'KM',
#    'Slug': 'comoros',
#    'NewConfirmed': 13,
#    'TotalConfirmed': 3996,
#    'NewDeaths': 0,
#    'TotalDeaths': 146,
#    'NewRecovered': 4,
#    'TotalRecovered': 3790,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'ab253cc8-9270-4b29-99a8-658a90637fc0',
#    'Country': 'Congo (Brazzaville)',
#    'CountryCode': 'CG',
#    'Slug': 'congo-brazzaville',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 12790,
#    'NewDeaths': 0,
#    'TotalDeaths': 167,
#    'NewRecovered': 0,
#    'TotalRecovered': 11759,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '09536206-22eb-452b-a948-2ff65020d3e6',
#    'Country': 'Congo (Kinshasa)',
#    'CountryCode': 'CD',
#    'Slug': 'congo-kinshasa',
#    'NewConfirmed': 169,
#    'TotalConfirmed': 44139,
#    'NewDeaths': 0,
#    'TotalDeaths': 980,
#    'NewRecovered': 0,
#    'TotalRecovered': 28630,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '255c1705-6e2d-450f-aef0-2eac138d9247',
#    'Country': 'Costa Rica',
#    'CountryCode': 'CR',
#    'Slug': 'costa-rica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 380482,
#    'NewDeaths': 0,
#    'TotalDeaths': 4773,
#    'NewRecovered': 0,
#    'TotalRecovered': 305426,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '08da3c83-d1a2-466b-8eaa-8e114f777f87',
#    'Country': 'Croatia',
#    'CountryCode': 'HR',
#    'Slug': 'croatia',
#    'NewConfirmed': 58,
#    'TotalConfirmed': 360826,
#    'NewDeaths': 0,
#    'TotalDeaths': 8227,
#    'NewRecovered': 71,
#    'TotalRecovered': 352007,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'ff002ee2-7c4a-4b77-8bed-5fb554db2afb',
#    'Country': 'Cuba',
#    'CountryCode': 'CU',
#    'Slug': 'cuba',
#    'NewConfirmed': 6923,
#    'TotalConfirmed': 238491,
#    'NewDeaths': 47,
#    'TotalDeaths': 1537,
#    'NewRecovered': 2993,
#    'TotalRecovered': 204810,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'f3fe19b2-9a74-410c-868c-b13ba06047c6',
#    'Country': 'Cyprus',
#    'CountryCode': 'CY',
#    'Slug': 'cyprus',
#    'NewConfirmed': 849,
#    'TotalConfirmed': 84272,
#    'NewDeaths': 0,
#    'TotalDeaths': 380,
#    'NewRecovered': 0,
#    'TotalRecovered': 39061,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '43b72ae4-15c8-4e37-b771-627f51d894ce',
#    'Country': 'Czech Republic',
#    'CountryCode': 'CZ',
#    'Slug': 'czech-republic',
#    'NewConfirmed': 169,
#    'TotalConfirmed': 1669351,
#    'NewDeaths': 0,
#    'TotalDeaths': 30331,
#    'NewRecovered': 227,
#    'TotalRecovered': 1637010,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '2ce60e77-bc77-4287-8cb8-812e8b969ec3',
#    'Country': "Côte d'Ivoire",
#    'CountryCode': 'CI',
#    'Slug': 'cote-divoire',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 48776,
#    'NewDeaths': 0,
#    'TotalDeaths': 318,
#    'NewRecovered': 0,
#    'TotalRecovered': 48085,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '7eba0d23-0520-46cb-affd-a5faed1ffc1b',
#    'Country': 'Denmark',
#    'CountryCode': 'DK',
#    'Slug': 'denmark',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 299511,
#    'NewDeaths': 0,
#    'TotalDeaths': 2540,
#    'NewRecovered': 0,
#    'TotalRecovered': 291049,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '8cf6daa2-6341-4458-bb9d-684a816cf75a',
#    'Country': 'Djibouti',
#    'CountryCode': 'DJ',
#    'Slug': 'djibouti',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 11615,
#    'NewDeaths': 0,
#    'TotalDeaths': 155,
#    'NewRecovered': 1,
#    'TotalRecovered': 11451,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '0fd005b2-a574-4784-9663-b918c15cd99e',
#    'Country': 'Dominica',
#    'CountryCode': 'DM',
#    'Slug': 'dominica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 197,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 192,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '863417cd-fcef-415b-90bb-3bec7844cbc7',
#    'Country': 'Dominican Republic',
#    'CountryCode': 'DO',
#    'Slug': 'dominican-republic',
#    'NewConfirmed': 628,
#    'TotalConfirmed': 333681,
#    'NewDeaths': 3,
#    'TotalDeaths': 3892,
#    'NewRecovered': 554,
#    'TotalRecovered': 273945,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'a2a48bfc-76c7-476c-994b-a0a1902b2d27',
#    'Country': 'Ecuador',
#    'CountryCode': 'EC',
#    'Slug': 'ecuador',
#    'NewConfirmed': 370,
#    'TotalConfirmed': 468346,
#    'NewDeaths': 16,
#    'TotalDeaths': 21830,
#    'NewRecovered': 5763,
#    'TotalRecovered': 437167,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '72cae38b-0783-480d-ae90-102f593e3ea6',
#    'Country': 'Egypt',
#    'CountryCode': 'EG',
#    'Slug': 'egypt',
#    'NewConfirmed': 117,
#    'TotalConfirmed': 283102,
#    'NewDeaths': 13,
#    'TotalDeaths': 16396,
#    'NewRecovered': 656,
#    'TotalRecovered': 218412,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '47a5d628-0399-499d-a7a8-6b8196a33a6d',
#    'Country': 'El Salvador',
#    'CountryCode': 'SV',
#    'Slug': 'el-salvador',
#    'NewConfirmed': 712,
#    'TotalConfirmed': 81644,
#    'NewDeaths': 6,
#    'TotalDeaths': 2445,
#    'NewRecovered': 427,
#    'TotalRecovered': 74388,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '53a3fa0a-bae9-4825-aec2-09bbb880381c',
#    'Country': 'Equatorial Guinea',
#    'CountryCode': 'GQ',
#    'Slug': 'equatorial-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8790,
#    'NewDeaths': 0,
#    'TotalDeaths': 122,
#    'NewRecovered': 0,
#    'TotalRecovered': 8572,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '6e1f003e-142d-463c-9bc0-b1b4b1520ed5',
#    'Country': 'Eritrea',
#    'CountryCode': 'ER',
#    'Slug': 'eritrea',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 6284,
#    'NewDeaths': 0,
#    'TotalDeaths': 29,
#    'NewRecovered': 0,
#    'TotalRecovered': 5842,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '6348707e-c45b-459d-90e0-cd54d1d7cd7b',
#    'Country': 'Estonia',
#    'CountryCode': 'EE',
#    'Slug': 'estonia',
#    'NewConfirmed': 27,
#    'TotalConfirmed': 131487,
#    'NewDeaths': 0,
#    'TotalDeaths': 1270,
#    'NewRecovered': 14,
#    'TotalRecovered': 127855,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '951f2a9d-098d-4f66-ac47-25db130aa442',
#    'Country': 'Ethiopia',
#    'CountryCode': 'ET',
#    'Slug': 'ethiopia',
#    'NewConfirmed': 87,
#    'TotalConfirmed': 277071,
#    'NewDeaths': 0,
#    'TotalDeaths': 4343,
#    'NewRecovered': 10,
#    'TotalRecovered': 261989,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '4641e853-a967-417c-b218-9e390264cdc5',
#    'Country': 'Fiji',
#    'CountryCode': 'FJ',
#    'Slug': 'fiji',
#    'NewConfirmed': 485,
#    'TotalConfirmed': 10512,
#    'NewDeaths': 3,
#    'TotalDeaths': 55,
#    'NewRecovered': 162,
#    'TotalRecovered': 1859,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '63badf0a-9759-4878-9f42-465c08db9db0',
#    'Country': 'Finland',
#    'CountryCode': 'FI',
#    'Slug': 'finland',
#    'NewConfirmed': 138,
#    'TotalConfirmed': 98082,
#    'NewDeaths': 0,
#    'TotalDeaths': 976,
#    'NewRecovered': 0,
#    'TotalRecovered': 46000,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'fe180dcc-f981-4537-ac6a-f64dde3356cf',
#    'Country': 'France',
#    'CountryCode': 'FR',
#    'Slug': 'france',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5870463,
#    'NewDeaths': 0,
#    'TotalDeaths': 111511,
#    'NewRecovered': 0,
#    'TotalRecovered': 407372,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '3b76db8b-a8af-46f7-88dc-2f8052af5b97',
#    'Country': 'Gabon',
#    'CountryCode': 'GA',
#    'Slug': 'gabon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 25164,
#    'NewDeaths': 0,
#    'TotalDeaths': 162,
#    'NewRecovered': 0,
#    'TotalRecovered': 24898,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'c16c7f12-c902-424d-8998-bfd2e23acfde',
#    'Country': 'Gambia',
#    'CountryCode': 'GM',
#    'Slug': 'gambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6282,
#    'NewDeaths': 0,
#    'TotalDeaths': 185,
#    'NewRecovered': 0,
#    'TotalRecovered': 5906,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '08ac5a85-df06-4d88-b061-5ed1bfbc9e93',
#    'Country': 'Georgia',
#    'CountryCode': 'GE',
#    'Slug': 'georgia',
#    'NewConfirmed': 952,
#    'TotalConfirmed': 377152,
#    'NewDeaths': 9,
#    'TotalDeaths': 5452,
#    'NewRecovered': 999,
#    'TotalRecovered': 359226,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '4c8fb230-2293-4ffb-a7cc-fbc2122c7c35',
#    'Country': 'Germany',
#    'CountryCode': 'DE',
#    'Slug': 'germany',
#    'NewConfirmed': 809,
#    'TotalConfirmed': 3743164,
#    'NewDeaths': 7,
#    'TotalDeaths': 91239,
#    'NewRecovered': 100,
#    'TotalRecovered': 3632330,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'd8a9f23b-f739-4825-85f9-8d73e4f1cc90',
#    'Country': 'Ghana',
#    'CountryCode': 'GH',
#    'Slug': 'ghana',
#    'NewConfirmed': 455,
#    'TotalConfirmed': 97585,
#    'NewDeaths': 2,
#    'TotalDeaths': 801,
#    'NewRecovered': 188,
#    'TotalRecovered': 94537,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '19fc778f-613a-4ad0-aa3d-4e795ae5fd77',
#    'Country': 'Greece',
#    'CountryCode': 'GR',
#    'Slug': 'greece',
#    'NewConfirmed': 1464,
#    'TotalConfirmed': 438809,
#    'NewDeaths': 5,
#    'TotalDeaths': 12768,
#    'NewRecovered': 0,
#    'TotalRecovered': 93764,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '9c35dec3-9c91-471f-b0c6-09d68edf8973',
#    'Country': 'Grenada',
#    'CountryCode': 'GD',
#    'Slug': 'grenada',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 161,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 160,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '5e767446-6271-49cd-8f23-467b28d4f639',
#    'Country': 'Guatemala',
#    'CountryCode': 'GT',
#    'Slug': 'guatemala',
#    'NewConfirmed': 1230,
#    'TotalConfirmed': 318541,
#    'NewDeaths': 25,
#    'TotalDeaths': 9713,
#    'NewRecovered': 1379,
#    'TotalRecovered': 279371,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '61d70cc2-5aa8-4b4b-a8dd-f8e5aa9ad6f4',
#    'Country': 'Guinea',
#    'CountryCode': 'GN',
#    'Slug': 'guinea',
#    'NewConfirmed': 52,
#    'TotalConfirmed': 24117,
#    'NewDeaths': 1,
#    'TotalDeaths': 177,
#    'NewRecovered': 12,
#    'TotalRecovered': 23370,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '276e9842-8c09-4b8c-b340-79b1391d9d2e',
#    'Country': 'Guinea-Bissau',
#    'CountryCode': 'GW',
#    'Slug': 'guinea-bissau',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 3947,
#    'NewDeaths': 0,
#    'TotalDeaths': 70,
#    'NewRecovered': 5,
#    'TotalRecovered': 3632,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'a6d43d67-d6a5-4288-bd69-df13c3fcba7a',
#    'Country': 'Guyana',
#    'CountryCode': 'GY',
#    'Slug': 'guyana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 20924,
#    'NewDeaths': 0,
#    'TotalDeaths': 492,
#    'NewRecovered': 0,
#    'TotalRecovered': 18998,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'c38280c4-2b14-4773-a69b-f64a2d935712',
#    'Country': 'Haiti',
#    'CountryCode': 'HT',
#    'Slug': 'haiti',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 19220,
#    'NewDeaths': 0,
#    'TotalDeaths': 471,
#    'NewRecovered': 0,
#    'TotalRecovered': 12961,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'e9a18671-546d-40bb-b978-d6c5c6fd88d7',
#    'Country': 'Holy See (Vatican City State)',
#    'CountryCode': 'VA',
#    'Slug': 'holy-see-vatican-city-state',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 27,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 27,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '203a9bfe-62a6-426b-bc90-72773d15a026',
#    'Country': 'Honduras',
#    'CountryCode': 'HN',
#    'Slug': 'honduras',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 273702,
#    'NewDeaths': 0,
#    'TotalDeaths': 7250,
#    'NewRecovered': 0,
#    'TotalRecovered': 94243,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '2086de4c-b262-487f-8255-44b8eaaa7ddc',
#    'Country': 'Hungary',
#    'CountryCode': 'HU',
#    'Slug': 'hungary',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 808437,
#    'NewDeaths': 0,
#    'TotalDeaths': 30004,
#    'NewRecovered': 0,
#    'TotalRecovered': 741083,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'f3c488d9-c043-47c4-a065-b70b60815638',
#    'Country': 'Iceland',
#    'CountryCode': 'IS',
#    'Slug': 'iceland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6555,
#    'NewDeaths': 0,
#    'TotalDeaths': 29,
#    'NewRecovered': 0,
#    'TotalRecovered': 6476,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '16902d77-4f50-49de-a821-fa715c69312f',
#    'Country': 'India',
#    'CountryCode': 'IN',
#    'Slug': 'india',
#    'NewConfirmed': 41506,
#    'TotalConfirmed': 30837222,
#    'NewDeaths': 895,
#    'TotalDeaths': 408040,
#    'NewRecovered': 41526,
#    'TotalRecovered': 29975064,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'b252c161-3510-4022-bd2e-aa7fc2a1f30f',
#    'Country': 'Indonesia',
#    'CountryCode': 'ID',
#    'Slug': 'indonesia',
#    'NewConfirmed': 36197,
#    'TotalConfirmed': 2527203,
#    'NewDeaths': 1007,
#    'TotalDeaths': 66464,
#    'NewRecovered': 32615,
#    'TotalRecovered': 2084724,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '1498eb14-1a64-46b7-a3e2-31f6dba5c9aa',
#    'Country': 'Iran, Islamic Republic of',
#    'CountryCode': 'IR',
#    'Slug': 'iran',
#    'NewConfirmed': 17664,
#    'TotalConfirmed': 3373450,
#    'NewDeaths': 165,
#    'TotalDeaths': 85859,
#    'NewRecovered': 15821,
#    'TotalRecovered': 3025911,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '9bbf5234-f5e2-4e66-914d-e47c1ba3d7ab',
#    'Country': 'Iraq',
#    'CountryCode': 'IQ',
#    'Slug': 'iraq',
#    'NewConfirmed': 7616,
#    'TotalConfirmed': 1429362,
#    'NewDeaths': 33,
#    'TotalDeaths': 17548,
#    'NewRecovered': 5937,
#    'TotalRecovered': 1306454,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '968c9823-ff10-41da-b92b-336aa30641e7',
#    'Country': 'Ireland',
#    'CountryCode': 'IE',
#    'Slug': 'ireland',
#    'NewConfirmed': 576,
#    'TotalConfirmed': 277892,
#    'NewDeaths': 0,
#    'TotalDeaths': 5006,
#    'NewRecovered': 0,
#    'TotalRecovered': 23364,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '6f31e8b0-dedb-4ca7-8f22-d626955e2864',
#    'Country': 'Israel',
#    'CountryCode': 'IL',
#    'Slug': 'israel',
#    'NewConfirmed': 323,
#    'TotalConfirmed': 846134,
#    'NewDeaths': 3,
#    'TotalDeaths': 6438,
#    'NewRecovered': 424,
#    'TotalRecovered': 835588,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '41073f7c-4680-46d6-8df9-4282e5b58264',
#    'Country': 'Italy',
#    'CountryCode': 'IT',
#    'Slug': 'italy',
#    'NewConfirmed': 1394,
#    'TotalConfirmed': 4269885,
#    'NewDeaths': 12,
#    'TotalDeaths': 127768,
#    'NewRecovered': 1763,
#    'TotalRecovered': 4101102,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'dd84d105-b2d9-4cc2-86c0-1b400271cadd',
#    'Country': 'Jamaica',
#    'CountryCode': 'JM',
#    'Slug': 'jamaica',
#    'NewConfirmed': 91,
#    'TotalConfirmed': 50720,
#    'NewDeaths': 16,
#    'TotalDeaths': 1130,
#    'NewRecovered': 1082,
#    'TotalRecovered': 39000,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'b34bac95-b103-418e-b72e-d009ba9554ba',
#    'Country': 'Japan',
#    'CountryCode': 'JP',
#    'Slug': 'japan',
#    'NewConfirmed': 2458,
#    'TotalConfirmed': 819051,
#    'NewDeaths': 11,
#    'TotalDeaths': 14896,
#    'NewRecovered': 1816,
#    'TotalRecovered': 783273,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '3bcb44d5-22b4-4e78-8086-edc439157460',
#    'Country': 'Jordan',
#    'CountryCode': 'JO',
#    'Slug': 'jordan',
#    'NewConfirmed': 569,
#    'TotalConfirmed': 756923,
#    'NewDeaths': 10,
#    'TotalDeaths': 9836,
#    'NewRecovered': 455,
#    'TotalRecovered': 739948,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'b789bbad-36a9-426d-9944-fec0b6cc7c23',
#    'Country': 'Kazakhstan',
#    'CountryCode': 'KZ',
#    'Slug': 'kazakhstan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 512685,
#    'NewDeaths': 0,
#    'TotalDeaths': 3569,
#    'NewRecovered': 0,
#    'TotalRecovered': 464930,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '41af9af0-f34f-44f3-90c4-f347121806ef',
#    'Country': 'Kenya',
#    'CountryCode': 'KE',
#    'Slug': 'kenya',
#    'NewConfirmed': 241,
#    'TotalConfirmed': 188754,
#    'NewDeaths': 1,
#    'TotalDeaths': 3722,
#    'NewRecovered': 1401,
#    'TotalRecovered': 179520,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'f0bb122f-2fed-4eab-8fe2-04e3bdc68d7c',
#    'Country': 'Kiribati',
#    'CountryCode': 'KI',
#    'Slug': 'kiribati',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '6bf780ac-ec96-4a97-a50d-b90ae8ccaf29',
#    'Country': 'Korea (South)',
#    'CountryCode': 'KR',
#    'Slug': 'korea-south',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 168046,
#    'NewDeaths': 0,
#    'TotalDeaths': 2043,
#    'NewRecovered': 0,
#    'TotalRecovered': 153760,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'a7a5b35d-d250-4a13-9fed-e241abe83f16',
#    'Country': 'Kuwait',
#    'CountryCode': 'KW',
#    'Slug': 'kuwait',
#    'NewConfirmed': 1490,
#    'TotalConfirmed': 375594,
#    'NewDeaths': 17,
#    'TotalDeaths': 2117,
#    'NewRecovered': 1626,
#    'TotalRecovered': 355562,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '86926549-bb68-4b07-b525-f8484fa70296',
#    'Country': 'Kyrgyzstan',
#    'CountryCode': 'KG',
#    'Slug': 'kyrgyzstan',
#    'NewConfirmed': 1295,
#    'TotalConfirmed': 139648,
#    'NewDeaths': 9,
#    'TotalDeaths': 2102,
#    'NewRecovered': 758,
#    'TotalRecovered': 118008,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '2431c9a5-30da-4471-a81b-f23918bc7fa8',
#    'Country': 'Lao PDR',
#    'CountryCode': 'LA',
#    'Slug': 'lao-pdr',
#    'NewConfirmed': 89,
#    'TotalConfirmed': 2719,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 2174,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '8a25f82d-a7b4-45fc-a0e3-8b8ca75e3313',
#    'Country': 'Latvia',
#    'CountryCode': 'LV',
#    'Slug': 'latvia',
#    'NewConfirmed': 36,
#    'TotalConfirmed': 137899,
#    'NewDeaths': 0,
#    'TotalDeaths': 2536,
#    'NewRecovered': 44,
#    'TotalRecovered': 134673,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'd3b9648a-db7e-43ee-9144-c82088f45849',
#    'Country': 'Lebanon',
#    'CountryCode': 'LB',
#    'Slug': 'lebanon',
#    'NewConfirmed': 314,
#    'TotalConfirmed': 547811,
#    'NewDeaths': 2,
#    'TotalDeaths': 7875,
#    'NewRecovered': 0,
#    'TotalRecovered': 534296,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '0a457aef-ba1e-4630-a931-a40b77a10a70',
#    'Country': 'Lesotho',
#    'CountryCode': 'LS',
#    'Slug': 'lesotho',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11903,
#    'NewDeaths': 0,
#    'TotalDeaths': 335,
#    'NewRecovered': 0,
#    'TotalRecovered': 6593,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '8f080106-17f0-49c1-946d-6b8360139dd1',
#    'Country': 'Liberia',
#    'CountryCode': 'LR',
#    'Slug': 'liberia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5102,
#    'NewDeaths': 0,
#    'TotalDeaths': 144,
#    'NewRecovered': 0,
#    'TotalRecovered': 2588,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'bcd7deb9-4a94-4784-9057-427e0897ef62',
#    'Country': 'Libya',
#    'CountryCode': 'LY',
#    'Slug': 'libya',
#    'NewConfirmed': 2854,
#    'TotalConfirmed': 204090,
#    'NewDeaths': 8,
#    'TotalDeaths': 3240,
#    'NewRecovered': 376,
#    'TotalRecovered': 180860,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '2c6236f6-9f01-4bb7-958f-88c8b1c35fc9',
#    'Country': 'Liechtenstein',
#    'CountryCode': 'LI',
#    'Slug': 'liechtenstein',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3056,
#    'NewDeaths': 0,
#    'TotalDeaths': 59,
#    'NewRecovered': 0,
#    'TotalRecovered': 2972,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '9975aa5a-b156-49ec-bcec-403cb673f535',
#    'Country': 'Lithuania',
#    'CountryCode': 'LT',
#    'Slug': 'lithuania',
#    'NewConfirmed': 25,
#    'TotalConfirmed': 279192,
#    'NewDeaths': 0,
#    'TotalDeaths': 4398,
#    'NewRecovered': 6,
#    'TotalRecovered': 268146,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '1bedc565-1d16-4e73-8f43-795e81eb5499',
#    'Country': 'Luxembourg',
#    'CountryCode': 'LU',
#    'Slug': 'luxembourg',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 72010,
#    'NewDeaths': 0,
#    'TotalDeaths': 819,
#    'NewRecovered': 0,
#    'TotalRecovered': 69836,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '5f0aa847-29b1-4e44-8814-f728593272d4',
#    'Country': 'Macedonia, Republic of',
#    'CountryCode': 'MK',
#    'Slug': 'macedonia',
#    'NewConfirmed': 14,
#    'TotalConfirmed': 155797,
#    'NewDeaths': 0,
#    'TotalDeaths': 5487,
#    'NewRecovered': 2,
#    'TotalRecovered': 150126,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '8602608d-54b1-4ee6-a17c-a20f06560e39',
#    'Country': 'Madagascar',
#    'CountryCode': 'MG',
#    'Slug': 'madagascar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 42392,
#    'NewDeaths': 0,
#    'TotalDeaths': 928,
#    'NewRecovered': 0,
#    'TotalRecovered': 40798,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '06306035-141e-4c09-be43-e7795d9e5e85',
#    'Country': 'Malawi',
#    'CountryCode': 'MW',
#    'Slug': 'malawi',
#    'NewConfirmed': 240,
#    'TotalConfirmed': 39186,
#    'NewDeaths': 8,
#    'TotalDeaths': 1250,
#    'NewRecovered': 16,
#    'TotalRecovered': 33854,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '92d822b4-f549-4f24-9c62-80fd62a86588',
#    'Country': 'Malaysia',
#    'CountryCode': 'MY',
#    'Slug': 'malaysia',
#    'NewConfirmed': 9105,
#    'TotalConfirmed': 836296,
#    'NewDeaths': 91,
#    'TotalDeaths': 6158,
#    'NewRecovered': 5194,
#    'TotalRecovered': 742297,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '25091666-70fd-4625-b61b-2abae05623bf',
#    'Country': 'Maldives',
#    'CountryCode': 'MV',
#    'Slug': 'maldives',
#    'NewConfirmed': 78,
#    'TotalConfirmed': 75071,
#    'NewDeaths': 1,
#    'TotalDeaths': 214,
#    'NewRecovered': 231,
#    'TotalRecovered': 72349,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'e096f3fd-1aa6-4ba2-a882-ff5e4af6daad',
#    'Country': 'Mali',
#    'CountryCode': 'ML',
#    'Slug': 'mali',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 14463,
#    'NewDeaths': 0,
#    'TotalDeaths': 528,
#    'NewRecovered': 2,
#    'TotalRecovered': 10102,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '7bc17c18-718f-4cc1-8fc4-0e0304db0424',
#    'Country': 'Malta',
#    'CountryCode': 'MT',
#    'Slug': 'malta',
#    'NewConfirmed': 101,
#    'TotalConfirmed': 31061,
#    'NewDeaths': 0,
#    'TotalDeaths': 420,
#    'NewRecovered': 3,
#    'TotalRecovered': 30184,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'c7623db2-d48e-4fde-ab9d-3c185c0980c6',
#    'Country': 'Marshall Islands',
#    'CountryCode': 'MH',
#    'Slug': 'marshall-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 4,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'cc48521c-3ffe-4378-b50a-f59457670c21',
#    'Country': 'Mauritania',
#    'CountryCode': 'MR',
#    'Slug': 'mauritania',
#    'NewConfirmed': 82,
#    'TotalConfirmed': 21672,
#    'NewDeaths': 1,
#    'TotalDeaths': 495,
#    'NewRecovered': 69,
#    'TotalRecovered': 20254,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'b5af8ec0-5f5e-49b8-b482-19ffffeb24df',
#    'Country': 'Mauritius',
#    'CountryCode': 'MU',
#    'Slug': 'mauritius',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1858,
#    'NewDeaths': 0,
#    'TotalDeaths': 18,
#    'NewRecovered': 0,
#    'TotalRecovered': 1534,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'b41bd686-93a7-43e2-8249-da104b5372b9',
#    'Country': 'Mexico',
#    'CountryCode': 'MX',
#    'Slug': 'mexico',
#    'NewConfirmed': 9581,
#    'TotalConfirmed': 2586721,
#    'NewDeaths': 232,
#    'TotalDeaths': 234907,
#    'NewRecovered': 4642,
#    'TotalRecovered': 2041418,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '47bc1902-d479-4ce1-a542-42303f8cc24c',
#    'Country': 'Micronesia, Federated States of',
#    'CountryCode': 'FM',
#    'Slug': 'micronesia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 1,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '783a334b-e910-4d31-b549-3f859f38dedf',
#    'Country': 'Moldova',
#    'CountryCode': 'MD',
#    'Slug': 'moldova',
#    'NewConfirmed': 48,
#    'TotalConfirmed': 257467,
#    'NewDeaths': 1,
#    'TotalDeaths': 6209,
#    'NewRecovered': 63,
#    'TotalRecovered': 250447,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '154c9420-0b61-4db5-b31f-d2d6441911fb',
#    'Country': 'Monaco',
#    'CountryCode': 'MC',
#    'Slug': 'monaco',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2622,
#    'NewDeaths': 0,
#    'TotalDeaths': 33,
#    'NewRecovered': 0,
#    'TotalRecovered': 2542,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '1cbdaa5b-e121-405e-8725-2e345e1561ba',
#    'Country': 'Mongolia',
#    'CountryCode': 'MN',
#    'Slug': 'mongolia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 137788,
#    'NewDeaths': 0,
#    'TotalDeaths': 684,
#    'NewRecovered': 0,
#    'TotalRecovered': 103666,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'becb0cfd-8313-4f1d-9f5b-1e65b60abbb5',
#    'Country': 'Montenegro',
#    'CountryCode': 'ME',
#    'Slug': 'montenegro',
#    'NewConfirmed': 19,
#    'TotalConfirmed': 100478,
#    'NewDeaths': 0,
#    'TotalDeaths': 1620,
#    'NewRecovered': 23,
#    'TotalRecovered': 98537,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'ae099a8a-d31e-41ff-aeab-2f4726b1462e',
#    'Country': 'Morocco',
#    'CountryCode': 'MA',
#    'Slug': 'morocco',
#    'NewConfirmed': 1057,
#    'TotalConfirmed': 542462,
#    'NewDeaths': 9,
#    'TotalDeaths': 9369,
#    'NewRecovered': 828,
#    'TotalRecovered': 524826,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'af64799f-4875-4f4a-85d2-bc02752aa9f6',
#    'Country': 'Mozambique',
#    'CountryCode': 'MZ',
#    'Slug': 'mozambique',
#    'NewConfirmed': 933,
#    'TotalConfirmed': 88868,
#    'NewDeaths': 20,
#    'TotalDeaths': 982,
#    'NewRecovered': 718,
#    'TotalRecovered': 73617,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'c7a1dc62-8235-4d30-833a-109e59fb5b69',
#    'Country': 'Myanmar',
#    'CountryCode': 'MM',
#    'Slug': 'myanmar',
#    'NewConfirmed': 3461,
#    'TotalConfirmed': 192213,
#    'NewDeaths': 82,
#    'TotalDeaths': 3838,
#    'NewRecovered': 1549,
#    'TotalRecovered': 146358,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '8a4fac5a-adbc-46d0-9146-5e8ea4b4ed46',
#    'Country': 'Namibia',
#    'CountryCode': 'NA',
#    'Slug': 'namibia',
#    'NewConfirmed': 1496,
#    'TotalConfirmed': 105595,
#    'NewDeaths': 80,
#    'TotalDeaths': 1991,
#    'NewRecovered': 1086,
#    'TotalRecovered': 77957,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '55e7f275-e127-43f7-b32c-b477469d2cd4',
#    'Country': 'Nepal',
#    'CountryCode': 'NP',
#    'Slug': 'nepal',
#    'NewConfirmed': 1237,
#    'TotalConfirmed': 655449,
#    'NewDeaths': 20,
#    'TotalDeaths': 9382,
#    'NewRecovered': 1533,
#    'TotalRecovered': 619894,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '17235487-00a5-4368-9d81-a24fb4418c50',
#    'Country': 'Netherlands',
#    'CountryCode': 'NL',
#    'Slug': 'netherlands',
#    'NewConfirmed': 10283,
#    'TotalConfirmed': 1719120,
#    'NewDeaths': 1,
#    'TotalDeaths': 17765,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'ae7223ef-b9d3-474f-bad9-6e70a35a4809',
#    'Country': 'New Zealand',
#    'CountryCode': 'NZ',
#    'Slug': 'new-zealand',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2768,
#    'NewDeaths': 0,
#    'TotalDeaths': 26,
#    'NewRecovered': 0,
#    'TotalRecovered': 2707,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '5b1ed2e8-adc7-4ed4-8cd5-9ddfa3e18734',
#    'Country': 'Nicaragua',
#    'CountryCode': 'NI',
#    'Slug': 'nicaragua',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8461,
#    'NewDeaths': 0,
#    'TotalDeaths': 192,
#    'NewRecovered': 0,
#    'TotalRecovered': 4225,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '8a4bdba4-8585-4b11-a805-7afa5bbaa2c2',
#    'Country': 'Niger',
#    'CountryCode': 'NE',
#    'Slug': 'niger',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5538,
#    'NewDeaths': 0,
#    'TotalDeaths': 194,
#    'NewRecovered': 0,
#    'TotalRecovered': 5230,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'c7b786c8-03d7-4a81-a0e6-741775843a5d',
#    'Country': 'Nigeria',
#    'CountryCode': 'NG',
#    'Slug': 'nigeria',
#    'NewConfirmed': 12,
#    'TotalConfirmed': 168552,
#    'NewDeaths': 2,
#    'TotalDeaths': 2124,
#    'NewRecovered': 8,
#    'TotalRecovered': 164439,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '3f80d985-1216-4315-b355-068fbe037940',
#    'Country': 'Norway',
#    'CountryCode': 'NO',
#    'Slug': 'norway',
#    'NewConfirmed': 97,
#    'TotalConfirmed': 133197,
#    'NewDeaths': 0,
#    'TotalDeaths': 796,
#    'NewRecovered': 0,
#    'TotalRecovered': 17998,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'c7bd362a-4c38-452a-9af3-354d82fe9b6a',
#    'Country': 'Oman',
#    'CountryCode': 'OM',
#    'Slug': 'oman',
#    'NewConfirmed': 3217,
#    'TotalConfirmed': 284905,
#    'NewDeaths': 52,
#    'TotalDeaths': 3423,
#    'NewRecovered': 7125,
#    'TotalRecovered': 257689,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'e5e42284-a670-4378-b393-35989cf2a566',
#    'Country': 'Pakistan',
#    'CountryCode': 'PK',
#    'Slug': 'pakistan',
#    'NewConfirmed': 1980,
#    'TotalConfirmed': 973284,
#    'NewDeaths': 27,
#    'TotalDeaths': 22582,
#    'NewRecovered': 908,
#    'TotalRecovered': 913203,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '200bab31-5a29-4214-8414-a112aa47ed37',
#    'Country': 'Palau',
#    'CountryCode': 'PW',
#    'Slug': 'palau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'a1daf9e2-f239-4a52-983a-978eb19e232b',
#    'Country': 'Palestinian Territory',
#    'CountryCode': 'PS',
#    'Slug': 'palestine',
#    'NewConfirmed': 53,
#    'TotalConfirmed': 315160,
#    'NewDeaths': 2,
#    'TotalDeaths': 3582,
#    'NewRecovered': 221,
#    'TotalRecovered': 309910,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '8691f416-0643-464d-9189-32a593806df8',
#    'Country': 'Panama',
#    'CountryCode': 'PA',
#    'Slug': 'panama',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 414647,
#    'NewDeaths': 0,
#    'TotalDeaths': 6627,
#    'NewRecovered': 0,
#    'TotalRecovered': 394465,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '6819ea7e-e457-4274-ba8c-76419dfd6d01',
#    'Country': 'Papua New Guinea',
#    'CountryCode': 'PG',
#    'Slug': 'papua-new-guinea',
#    'NewConfirmed': 48,
#    'TotalConfirmed': 17340,
#    'NewDeaths': 2,
#    'TotalDeaths': 179,
#    'NewRecovered': 457,
#    'TotalRecovered': 16975,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '73109fc1-100e-4c65-a24d-68a6280a2930',
#    'Country': 'Paraguay',
#    'CountryCode': 'PY',
#    'Slug': 'paraguay',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 436624,
#    'NewDeaths': 0,
#    'TotalDeaths': 13867,
#    'NewRecovered': 0,
#    'TotalRecovered': 391681,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '953dd833-d97a-4523-b2cf-116c47435524',
#    'Country': 'Peru',
#    'CountryCode': 'PE',
#    'Slug': 'peru',
#    'NewConfirmed': 4629,
#    'TotalConfirmed': 2078815,
#    'NewDeaths': 0,
#    'TotalDeaths': 193909,
#    'NewRecovered': 4847,
#    'TotalRecovered': 2039864,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'bfa889dc-2ee1-4163-85cd-3e83ed9de4f5',
#    'Country': 'Philippines',
#    'CountryCode': 'PH',
#    'Slug': 'philippines',
#    'NewConfirmed': 5906,
#    'TotalConfirmed': 1473025,
#    'NewDeaths': 105,
#    'TotalDeaths': 25921,
#    'NewRecovered': 6068,
#    'TotalRecovered': 1397403,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'a07bc180-3f04-461d-9cb0-7fc986d3a6ae',
#    'Country': 'Poland',
#    'CountryCode': 'PL',
#    'Slug': 'poland',
#    'NewConfirmed': 66,
#    'TotalConfirmed': 2880821,
#    'NewDeaths': 1,
#    'TotalDeaths': 75160,
#    'NewRecovered': 47,
#    'TotalRecovered': 2652505,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'e66e245d-bac5-413c-9912-895570699127',
#    'Country': 'Portugal',
#    'CountryCode': 'PT',
#    'Slug': 'portugal',
#    'NewConfirmed': 2323,
#    'TotalConfirmed': 907974,
#    'NewDeaths': 8,
#    'TotalDeaths': 17156,
#    'NewRecovered': 1019,
#    'TotalRecovered': 845516,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '78979737-1fe9-41cd-b890-624624855690',
#    'Country': 'Qatar',
#    'CountryCode': 'QA',
#    'Slug': 'qatar',
#    'NewConfirmed': 86,
#    'TotalConfirmed': 223358,
#    'NewDeaths': 0,
#    'TotalDeaths': 599,
#    'NewRecovered': 135,
#    'TotalRecovered': 221295,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '89e375da-3d84-422d-9482-e907e2b4e0a5',
#    'Country': 'Republic of Kosovo',
#    'CountryCode': 'XK',
#    'Slug': 'kosovo',
#    'NewConfirmed': 12,
#    'TotalConfirmed': 107854,
#    'NewDeaths': 0,
#    'TotalDeaths': 2268,
#    'NewRecovered': 13,
#    'TotalRecovered': 105457,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'b79b14dd-a2fc-4b3a-af87-7cc62f4ecd2c',
#    'Country': 'Romania',
#    'CountryCode': 'RO',
#    'Slug': 'romania',
#    'NewConfirmed': 26,
#    'TotalConfirmed': 1081236,
#    'NewDeaths': 1,
#    'TotalDeaths': 34217,
#    'NewRecovered': 0,
#    'TotalRecovered': 1045351,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '416a28ba-3a30-4d78-9a76-ac7c887a705f',
#    'Country': 'Russian Federation',
#    'CountryCode': 'RU',
#    'Slug': 'russia',
#    'NewConfirmed': 24607,
#    'TotalConfirmed': 5688807,
#    'NewDeaths': 740,
#    'TotalDeaths': 139896,
#    'NewRecovered': 17395,
#    'TotalRecovered': 5122104,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '26890bed-7bf3-468d-96f9-afc1dba927ee',
#    'Country': 'Rwanda',
#    'CountryCode': 'RW',
#    'Slug': 'rwanda',
#    'NewConfirmed': 577,
#    'TotalConfirmed': 48244,
#    'NewDeaths': 9,
#    'TotalDeaths': 560,
#    'NewRecovered': 517,
#    'TotalRecovered': 32523,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '944a1694-883a-4e4e-a33c-3f775f6bb28f',
#    'Country': 'Saint Kitts and Nevis',
#    'CountryCode': 'KN',
#    'Slug': 'saint-kitts-and-nevis',
#    'NewConfirmed': 5,
#    'TotalConfirmed': 530,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 377,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '9b82a8dc-5017-4545-ac9e-bd65d25e7556',
#    'Country': 'Saint Lucia',
#    'CountryCode': 'LC',
#    'Slug': 'saint-lucia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5399,
#    'NewDeaths': 0,
#    'TotalDeaths': 86,
#    'NewRecovered': 0,
#    'TotalRecovered': 5188,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '7353d814-578a-4817-8feb-3820cc164346',
#    'Country': 'Saint Vincent and Grenadines',
#    'CountryCode': 'VC',
#    'Slug': 'saint-vincent-and-the-grenadines',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 2242,
#    'NewDeaths': 0,
#    'TotalDeaths': 12,
#    'NewRecovered': 5,
#    'TotalRecovered': 2146,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '7707fe6a-bd00-4b03-bb3b-e2cccae0078e',
#    'Country': 'Samoa',
#    'CountryCode': 'WS',
#    'Slug': 'samoa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 3,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'f675e1a8-13f4-4d40-b2ea-adbdec80ef90',
#    'Country': 'San Marino',
#    'CountryCode': 'SM',
#    'Slug': 'san-marino',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5092,
#    'NewDeaths': 0,
#    'TotalDeaths': 90,
#    'NewRecovered': 0,
#    'TotalRecovered': 5002,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'edbc7387-41fd-4239-91c8-ad05aa0f874c',
#    'Country': 'Sao Tome and Principe',
#    'CountryCode': 'ST',
#    'Slug': 'sao-tome-and-principe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2392,
#    'NewDeaths': 0,
#    'TotalDeaths': 37,
#    'NewRecovered': 0,
#    'TotalRecovered': 2327,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '4205b3c3-6a03-4713-81d9-554dc02a5933',
#    'Country': 'Saudi Arabia',
#    'CountryCode': 'SA',
#    'Slug': 'saudi-arabia',
#    'NewConfirmed': 1112,
#    'TotalConfirmed': 501195,
#    'NewDeaths': 13,
#    'TotalDeaths': 7976,
#    'NewRecovered': 1189,
#    'TotalRecovered': 482414,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '1b9d25b5-55d8-40e9-ba20-3cdcf10c6a7f',
#    'Country': 'Senegal',
#    'CountryCode': 'SN',
#    'Slug': 'senegal',
#    'NewConfirmed': 529,
#    'TotalConfirmed': 46175,
#    'NewDeaths': 4,
#    'TotalDeaths': 1194,
#    'NewRecovered': 106,
#    'TotalRecovered': 42308,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '09cfe7ba-72e2-49e6-9997-5a3574f852f7',
#    'Country': 'Serbia',
#    'CountryCode': 'RS',
#    'Slug': 'serbia',
#    'NewConfirmed': 69,
#    'TotalConfirmed': 717549,
#    'NewDeaths': 2,
#    'TotalDeaths': 7072,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'a3d17689-8988-4101-a104-376177ca3ef5',
#    'Country': 'Seychelles',
#    'CountryCode': 'SC',
#    'Slug': 'seychelles',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 16679,
#    'NewDeaths': 0,
#    'TotalDeaths': 74,
#    'NewRecovered': 0,
#    'TotalRecovered': 15541,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '8f9da27c-f936-45bd-a92b-c5b7d00f99db',
#    'Country': 'Sierra Leone',
#    'CountryCode': 'SL',
#    'Slug': 'sierra-leone',
#    'NewConfirmed': 28,
#    'TotalConfirmed': 6031,
#    'NewDeaths': 2,
#    'TotalDeaths': 112,
#    'NewRecovered': 36,
#    'TotalRecovered': 3963,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '5811fc25-5adc-41b2-ba18-60fac0b12951',
#    'Country': 'Singapore',
#    'CountryCode': 'SG',
#    'Slug': 'singapore',
#    'NewConfirmed': 8,
#    'TotalConfirmed': 62692,
#    'NewDeaths': 0,
#    'TotalDeaths': 36,
#    'NewRecovered': 17,
#    'TotalRecovered': 62414,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'bf144da8-0a94-4ed1-886f-042ce9b83761',
#    'Country': 'Slovakia',
#    'CountryCode': 'SK',
#    'Slug': 'slovakia',
#    'NewConfirmed': 25,
#    'TotalConfirmed': 391918,
#    'NewDeaths': 0,
#    'TotalDeaths': 12519,
#    'NewRecovered': 0,
#    'TotalRecovered': 255300,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '875ff7fa-3de5-4428-8488-b73e97d07116',
#    'Country': 'Slovenia',
#    'CountryCode': 'SI',
#    'Slug': 'slovenia',
#    'NewConfirmed': 25,
#    'TotalConfirmed': 257863,
#    'NewDeaths': 0,
#    'TotalDeaths': 4423,
#    'NewRecovered': 19,
#    'TotalRecovered': 252875,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '7faf4527-fea4-4568-870e-20edba29d901',
#    'Country': 'Solomon Islands',
#    'CountryCode': 'SB',
#    'Slug': 'solomon-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 20,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 20,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'd99ed51c-ad68-4796-a528-d086eb08e14b',
#    'Country': 'Somalia',
#    'CountryCode': 'SO',
#    'Slug': 'somalia',
#    'NewConfirmed': 41,
#    'TotalConfirmed': 15036,
#    'NewDeaths': 2,
#    'TotalDeaths': 777,
#    'NewRecovered': 9,
#    'TotalRecovered': 7261,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'c273ceb1-0377-45f9-b208-d166201aec0f',
#    'Country': 'South Africa',
#    'CountryCode': 'ZA',
#    'Slug': 'south-africa',
#    'NewConfirmed': 16302,
#    'TotalConfirmed': 2195599,
#    'NewDeaths': 151,
#    'TotalDeaths': 64289,
#    'NewRecovered': 18494,
#    'TotalRecovered': 1922601,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'ac6e9bf9-ddcc-4e6f-b77f-a9150d3c5e83',
#    'Country': 'South Sudan',
#    'CountryCode': 'SS',
#    'Slug': 'south-sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 10891,
#    'NewDeaths': 0,
#    'TotalDeaths': 117,
#    'NewRecovered': 0,
#    'TotalRecovered': 10514,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '3488a302-7b2c-4bc6-90d3-f4f28035191d',
#    'Country': 'Spain',
#    'CountryCode': 'ES',
#    'Slug': 'spain',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3937192,
#    'NewDeaths': 0,
#    'TotalDeaths': 81003,
#    'NewRecovered': 0,
#    'TotalRecovered': 150376,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '8bba3442-226e-4f4d-982a-fb68a17d1eb2',
#    'Country': 'Sri Lanka',
#    'CountryCode': 'LK',
#    'Slug': 'sri-lanka',
#    'NewConfirmed': 1507,
#    'TotalConfirmed': 274538,
#    'NewDeaths': 35,
#    'TotalDeaths': 3502,
#    'NewRecovered': 1598,
#    'TotalRecovered': 244437,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'c89c4e98-9b73-47f5-90bb-630e9404ec8e',
#    'Country': 'Sudan',
#    'CountryCode': 'SD',
#    'Slug': 'sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 36805,
#    'NewDeaths': 0,
#    'TotalDeaths': 2760,
#    'NewRecovered': 0,
#    'TotalRecovered': 30647,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'd302d8cc-32d1-49c6-8d9a-7be2ca8c175e',
#    'Country': 'Suriname',
#    'CountryCode': 'SR',
#    'Slug': 'suriname',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 23293,
#    'NewDeaths': 0,
#    'TotalDeaths': 575,
#    'NewRecovered': 0,
#    'TotalRecovered': 19280,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '64bff0b3-f51f-494f-a63f-99a26d7e06ee',
#    'Country': 'Swaziland',
#    'CountryCode': 'SZ',
#    'Slug': 'swaziland',
#    'NewConfirmed': 48,
#    'TotalConfirmed': 19918,
#    'NewDeaths': 5,
#    'TotalDeaths': 692,
#    'NewRecovered': 11,
#    'TotalRecovered': 18466,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'ae1e2599-f9ba-4fa6-8b9d-eaaae09bd062',
#    'Country': 'Sweden',
#    'CountryCode': 'SE',
#    'Slug': 'sweden',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1092540,
#    'NewDeaths': 0,
#    'TotalDeaths': 14643,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '8151ca0d-36b2-473a-bf60-baf2ae65fbf0',
#    'Country': 'Switzerland',
#    'CountryCode': 'CH',
#    'Slug': 'switzerland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 704943,
#    'NewDeaths': 0,
#    'TotalDeaths': 10898,
#    'NewRecovered': 0,
#    'TotalRecovered': 317600,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'c2bdab67-f688-47d9-a755-52000e0c40d1',
#    'Country': 'Syrian Arab Republic (Syria)',
#    'CountryCode': 'SY',
#    'Slug': 'syria',
#    'NewConfirmed': 19,
#    'TotalConfirmed': 25785,
#    'NewDeaths': 2,
#    'TotalDeaths': 1898,
#    'NewRecovered': 8,
#    'TotalRecovered': 21884,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '7e8f59e1-4d03-4dff-b1e2-08c82262d8df',
#    'Country': 'Taiwan, Republic of China',
#    'CountryCode': 'TW',
#    'Slug': 'taiwan',
#    'NewConfirmed': 31,
#    'TotalConfirmed': 15249,
#    'NewDeaths': 4,
#    'TotalDeaths': 740,
#    'NewRecovered': 104,
#    'TotalRecovered': 11802,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'e68d8578-9823-442d-be98-b702832b9d6d',
#    'Country': 'Tajikistan',
#    'CountryCode': 'TJ',
#    'Slug': 'tajikistan',
#    'NewConfirmed': 38,
#    'TotalConfirmed': 13834,
#    'NewDeaths': 1,
#    'TotalDeaths': 103,
#    'NewRecovered': 21,
#    'TotalRecovered': 13535,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'b35410ac-8815-41c8-a8a7-cfba8d96bae4',
#    'Country': 'Tanzania, United Republic of',
#    'CountryCode': 'TZ',
#    'Slug': 'tanzania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 509,
#    'NewDeaths': 0,
#    'TotalDeaths': 21,
#    'NewRecovered': 0,
#    'TotalRecovered': 183,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'aab1268a-9483-46e5-95ed-2ac11b231530',
#    'Country': 'Thailand',
#    'CountryCode': 'TH',
#    'Slug': 'thailand',
#    'NewConfirmed': 9539,
#    'TotalConfirmed': 336371,
#    'NewDeaths': 86,
#    'TotalDeaths': 2711,
#    'NewRecovered': 0,
#    'TotalRecovered': 26873,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '24579c2a-3d74-4aae-90b9-ee527ba737bc',
#    'Country': 'Timor-Leste',
#    'CountryCode': 'TL',
#    'Slug': 'timor-leste',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9766,
#    'NewDeaths': 0,
#    'TotalDeaths': 25,
#    'NewRecovered': 0,
#    'TotalRecovered': 8835,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'dc300f1f-8299-4f99-b05f-4db93b0a10be',
#    'Country': 'Togo',
#    'CountryCode': 'TG',
#    'Slug': 'togo',
#    'NewConfirmed': 38,
#    'TotalConfirmed': 14270,
#    'NewDeaths': 0,
#    'TotalDeaths': 133,
#    'NewRecovered': 10,
#    'TotalRecovered': 13656,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '1bb363d7-3865-4411-acc6-b79f8450c45e',
#    'Country': 'Trinidad and Tobago',
#    'CountryCode': 'TT',
#    'Slug': 'trinidad-and-tobago',
#    'NewConfirmed': 188,
#    'TotalConfirmed': 34765,
#    'NewDeaths': 2,
#    'TotalDeaths': 937,
#    'NewRecovered': 239,
#    'TotalRecovered': 27788,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '2a270d9f-e249-4184-a8c4-6b0c829c0240',
#    'Country': 'Tunisia',
#    'CountryCode': 'TN',
#    'Slug': 'tunisia',
#    'NewConfirmed': 6592,
#    'TotalConfirmed': 497613,
#    'NewDeaths': 144,
#    'TotalDeaths': 16388,
#    'NewRecovered': 5288,
#    'TotalRecovered': 393305,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'c9f1e33d-2ef7-472e-8524-f58341091ad8',
#    'Country': 'Turkey',
#    'CountryCode': 'TR',
#    'Slug': 'turkey',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5465094,
#    'NewDeaths': 0,
#    'TotalDeaths': 50096,
#    'NewRecovered': 0,
#    'TotalRecovered': 5333759,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '9e2878c9-f45a-430f-b358-56e79b90457b',
#    'Country': 'Uganda',
#    'CountryCode': 'UG',
#    'Slug': 'uganda',
#    'NewConfirmed': 522,
#    'TotalConfirmed': 87277,
#    'NewDeaths': 14,
#    'TotalDeaths': 2104,
#    'NewRecovered': 912,
#    'TotalRecovered': 61304,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '37e2c07c-a105-4d71-a6b9-8858598fa3c4',
#    'Country': 'Ukraine',
#    'CountryCode': 'UA',
#    'Slug': 'ukraine',
#    'NewConfirmed': 982,
#    'TotalConfirmed': 2310246,
#    'NewDeaths': 32,
#    'TotalDeaths': 54949,
#    'NewRecovered': 1164,
#    'TotalRecovered': 2237652,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '3268fa30-b2f5-48e2-840b-27f0e6fa1de4',
#    'Country': 'United Arab Emirates',
#    'CountryCode': 'AE',
#    'Slug': 'united-arab-emirates',
#    'NewConfirmed': 1518,
#    'TotalConfirmed': 650220,
#    'NewDeaths': 6,
#    'TotalDeaths': 1866,
#    'NewRecovered': 1490,
#    'TotalRecovered': 628290,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'ab0065fa-6070-4d20-aac9-4a52b5d8676b',
#    'Country': 'United Kingdom',
#    'CountryCode': 'GB',
#    'Slug': 'united-kingdom',
#    'NewConfirmed': 31835,
#    'TotalConfirmed': 5107780,
#    'NewDeaths': 34,
#    'TotalDeaths': 128665,
#    'NewRecovered': 4,
#    'TotalRecovered': 15892,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '95e72dde-d3e5-469a-8884-f8f11e4b1dd8',
#    'Country': 'United States of America',
#    'CountryCode': 'US',
#    'Slug': 'united-states',
#    'NewConfirmed': 9038,
#    'TotalConfirmed': 33847784,
#    'NewDeaths': 139,
#    'TotalDeaths': 607132,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'fdc1e194-5b5a-4061-a00c-2c18f3aeff59',
#    'Country': 'Uruguay',
#    'CountryCode': 'UY',
#    'Slug': 'uruguay',
#    'NewConfirmed': 298,
#    'TotalConfirmed': 376579,
#    'NewDeaths': 8,
#    'TotalDeaths': 5815,
#    'NewRecovered': 862,
#    'TotalRecovered': 363544,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '4d74d233-85bf-459c-ad6f-a1227389d8ea',
#    'Country': 'Uzbekistan',
#    'CountryCode': 'UZ',
#    'Slug': 'uzbekistan',
#    'NewConfirmed': 485,
#    'TotalConfirmed': 115963,
#    'NewDeaths': 4,
#    'TotalDeaths': 771,
#    'NewRecovered': 430,
#    'TotalRecovered': 111189,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '0cb1a2c5-0e06-4891-b385-d37576ba65b6',
#    'Country': 'Vanuatu',
#    'CountryCode': 'VU',
#    'Slug': 'vanuatu',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 3,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '0db541cc-a942-426b-86e4-488838459a20',
#    'Country': 'Venezuela (Bolivarian Republic)',
#    'CountryCode': 'VE',
#    'Slug': 'venezuela',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 283742,
#    'NewDeaths': 0,
#    'TotalDeaths': 3278,
#    'NewRecovered': 0,
#    'TotalRecovered': 266231,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '677aa68c-8c9e-4d85-a52e-644fab37ccba',
#    'Country': 'Viet Nam',
#    'CountryCode': 'VN',
#    'Slug': 'vietnam',
#    'NewConfirmed': 1346,
#    'TotalConfirmed': 29816,
#    'NewDeaths': 7,
#    'TotalDeaths': 119,
#    'NewRecovered': 71,
#    'TotalRecovered': 9275,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': 'a7a47427-b543-4f9c-93bc-d10ddecdf0aa',
#    'Country': 'Yemen',
#    'CountryCode': 'YE',
#    'Slug': 'yemen',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 6948,
#    'NewDeaths': 0,
#    'TotalDeaths': 1366,
#    'NewRecovered': 6,
#    'TotalRecovered': 4141,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '5e72ac3a-ea32-4f8f-814c-5a69bac44c1f',
#    'Country': 'Zambia',
#    'CountryCode': 'ZM',
#    'Slug': 'zambia',
#    'NewConfirmed': 940,
#    'TotalConfirmed': 175729,
#    'NewDeaths': 47,
#    'TotalDeaths': 2822,
#    'NewRecovered': 2726,
#    'TotalRecovered': 160215,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}},
#   {'ID': '27f80f9f-78b1-4a25-ba24-1b6283118789',
#    'Country': 'Zimbabwe',
#    'CountryCode': 'ZW',
#    'Slug': 'zimbabwe',
#    'NewConfirmed': 912,
#    'TotalConfirmed': 67765,
#    'NewDeaths': 59,
#    'TotalDeaths': 2185,
#    'NewRecovered': 1037,
#    'TotalRecovered': 45617,
#    'Date': '2021-07-12T04:09:49.631Z',
#    'Premium': {}}],
#  'Date': '2021-07-12T04:09:49.631Z'}

# %% [markdown]
# #### Normalize data

# %%
pd.json_normalize(covid1['Countries'],sep=",")
# Out:
#                                        ID                          Country  \
# 0    5c1da4d5-84d6-46bb-a883-d351e5348249                      Afghanistan
# 1    2e99b380-2887-4f55-bb12-0b029ed7e9a5                          Albania
# 2    2a76ca19-d8db-43b9-b7f7-90c8da735df1                          Algeria
# 3    a70ef799-d1c6-4f45-9db3-744821919fbc                          Andorra
# 4    ebccbf43-269d-4f07-b5bc-7c55bada024d                           Angola
# ..                                    ...                              ...
# 187  0db541cc-a942-426b-86e4-488838459a20  Venezuela (Bolivarian Republic)
# 188  677aa68c-8c9e-4d85-a52e-644fab37ccba                         Viet Nam
# 189  a7a47427-b543-4f9c-93bc-d10ddecdf0aa                            Yemen
# 190  5e72ac3a-ea32-4f8f-814c-5a69bac44c1f                           Zambia
# 191  27f80f9f-78b1-4a25-ba24-1b6283118789                         Zimbabwe
#
#     CountryCode         Slug  NewConfirmed  TotalConfirmed  NewDeaths  \
# 0            AF  afghanistan             0          131586          0
# 1            AL      albania             5          132592          0
# 2            DZ      algeria           768          146064         12
# 3            AD      andorra             0           14075          0
# 4            AO       angola             0           39881          0
# ..          ...          ...           ...             ...        ...
# 187          VE    venezuela             0          283742          0
# 188          VN      vietnam          1346           29816          7
# 189          YE        yemen             7            6948          0
# 190          ZM       zambia           940          175729         47
# 191          ZW     zimbabwe           912           67765         59
#
#      TotalDeaths  NewRecovered  TotalRecovered                      Date
# 0           5561           851           81077  2021-07-12T04:09:49.631Z
# 1           2456             3          130050  2021-07-12T04:09:49.631Z
# 2           3836           519          101430  2021-07-12T04:09:49.631Z
# 3            127             0           13770  2021-07-12T04:09:49.631Z
# 4            929             0           34298  2021-07-12T04:09:49.631Z
# ..           ...           ...             ...                       ...
# 187         3278             0          266231  2021-07-12T04:09:49.631Z
# 188          119            71            9275  2021-07-12T04:09:49.631Z
# 189         1366             6            4141  2021-07-12T04:09:49.631Z
# 190         2822          2726          160215  2021-07-12T04:09:49.631Z
# 191         2185          1037           45617  2021-07-12T04:09:49.631Z
#
# [192 rows x 11 columns]

# %% [markdown]
# #### Geerate Pandas DataFrame from Covid Data

# %%
df = pd.DataFrame(covid1['Countries'])
df
# Out:
#                                        ID                          Country  \
# 0    5c1da4d5-84d6-46bb-a883-d351e5348249                      Afghanistan
# 1    2e99b380-2887-4f55-bb12-0b029ed7e9a5                          Albania
# 2    2a76ca19-d8db-43b9-b7f7-90c8da735df1                          Algeria
# 3    a70ef799-d1c6-4f45-9db3-744821919fbc                          Andorra
# 4    ebccbf43-269d-4f07-b5bc-7c55bada024d                           Angola
# ..                                    ...                              ...
# 187  0db541cc-a942-426b-86e4-488838459a20  Venezuela (Bolivarian Republic)
# 188  677aa68c-8c9e-4d85-a52e-644fab37ccba                         Viet Nam
# 189  a7a47427-b543-4f9c-93bc-d10ddecdf0aa                            Yemen
# 190  5e72ac3a-ea32-4f8f-814c-5a69bac44c1f                           Zambia
# 191  27f80f9f-78b1-4a25-ba24-1b6283118789                         Zimbabwe
#
#     CountryCode         Slug  NewConfirmed  TotalConfirmed  NewDeaths  \
# 0            AF  afghanistan             0          131586          0
# 1            AL      albania             5          132592          0
# 2            DZ      algeria           768          146064         12
# 3            AD      andorra             0           14075          0
# 4            AO       angola             0           39881          0
# ..          ...          ...           ...             ...        ...
# 187          VE    venezuela             0          283742          0
# 188          VN      vietnam          1346           29816          7
# 189          YE        yemen             7            6948          0
# 190          ZM       zambia           940          175729         47
# 191          ZW     zimbabwe           912           67765         59
#
#      TotalDeaths  NewRecovered  TotalRecovered                      Date  \
# 0           5561           851           81077  2021-07-12T04:09:49.631Z
# 1           2456             3          130050  2021-07-12T04:09:49.631Z
# 2           3836           519          101430  2021-07-12T04:09:49.631Z
# 3            127             0           13770  2021-07-12T04:09:49.631Z
# 4            929             0           34298  2021-07-12T04:09:49.631Z
# ..           ...           ...             ...                       ...
# 187         3278             0          266231  2021-07-12T04:09:49.631Z
# 188          119            71            9275  2021-07-12T04:09:49.631Z
# 189         1366             6            4141  2021-07-12T04:09:49.631Z
# 190         2822          2726          160215  2021-07-12T04:09:49.631Z
# 191         2185          1037           45617  2021-07-12T04:09:49.631Z
#
#     Premium
# 0        {}
# 1        {}
# 2        {}
# 3        {}
# 4        {}
# ..      ...
# 187      {}
# 188      {}
# 189      {}
# 190      {}
# 191      {}
#
# [192 rows x 12 columns]

# %% [markdown]
# Clean the data by droppig unnecessary columns

# %%
covid2 = df.drop(columns =['CountryCode','Slug','Date','Premium'],axis=1)

# %% [markdown]
# #### Generate Base Map

# %%
m = folium.Map(tiles="Stamen Terrain", min_zoom=1.5)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d1ee392d6fbf45609d1a7f76b9d0537d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d1ee392d6fbf45609d1a7f76b9d0537d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_d1ee392d6fbf45609d1a7f76b9d0537d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_d1ee392d6fbf45609d1a7f76b9d0537d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %% [markdown]
# ##### Obtain Geo-Coordinates

# %%
url = 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
country_shapes = f'{url}/world-countries.json'

# %% [markdown]
# #### Add Choropleth Layer to base map

# %%
folium.Choropleth(
    geo_data=country_shapes,
    min_zoom=2,
    name='COVID-19',
    data=covid2,
    columns=['Country', 'TotalConfirmed'],
    key_on='feature.properties.name',
    fill_color='OrRd',
    nan_fill_color='black',
    legend_name='Total Confirmed Covid Cases',
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d1ee392d6fbf45609d1a7f76b9d0537d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d1ee392d6fbf45609d1a7f76b9d0537d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_d1ee392d6fbf45609d1a7f76b9d0537d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_d1ee392d6fbf45609d1a7f76b9d0537d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# #### Generating Circular PopUps to showcase information on the map

# %%
covid2.update(covid2['TotalConfirmed'].map('Total Confirmed:{}'.format))
covid2.update(covid2['TotalRecovered'].map('Total Recovered:{}'.format))

# %%
coordinates = pd.read_csv('https://raw.githubusercontent.com/VinitaSilaparasetty/covid-map/master/country-coordinates-world.csv')
coordinates
# Out:
#       latitude   longitude            Country
# 0    33.939110   67.709953        Afghanistan
# 1    41.153332   20.168331            Albania
# 2    28.033886    1.659626            Algeria
# 3   -14.270972 -170.132217     American Samoa
# 4    42.546245    1.601554            Andorra
# ..         ...         ...                ...
# 239 -13.768752 -177.156097  Wallis and Futuna
# 240  24.215527  -12.885834     Western Sahara
# 241  15.552727   48.516388              Yemen
# 242 -13.133897   27.849332             Zambia
# 243 -19.015438   29.154857           Zimbabwe
#
# [244 rows x 3 columns]

# %%
covid_final= pd.merge(covid2,coordinates,on='Country')
covid_final
# Out:
#                                        ID      Country  NewConfirmed  \
# 0    5c1da4d5-84d6-46bb-a883-d351e5348249  Afghanistan             0
# 1    2e99b380-2887-4f55-bb12-0b029ed7e9a5      Albania             5
# 2    2a76ca19-d8db-43b9-b7f7-90c8da735df1      Algeria           768
# 3    a70ef799-d1c6-4f45-9db3-744821919fbc      Andorra             0
# 4    ebccbf43-269d-4f07-b5bc-7c55bada024d       Angola             0
# ..                                    ...          ...           ...
# 166  4d74d233-85bf-459c-ad6f-a1227389d8ea   Uzbekistan           485
# 167  0cb1a2c5-0e06-4891-b385-d37576ba65b6      Vanuatu             0
# 168  a7a47427-b543-4f9c-93bc-d10ddecdf0aa        Yemen             7
# 169  5e72ac3a-ea32-4f8f-814c-5a69bac44c1f       Zambia           940
# 170  27f80f9f-78b1-4a25-ba24-1b6283118789     Zimbabwe           912
#
#              TotalConfirmed  NewDeaths  TotalDeaths  NewRecovered  \
# 0    Total Confirmed:131586          0         5561           851
# 1    Total Confirmed:132592          0         2456             3
# 2    Total Confirmed:146064         12         3836           519
# 3     Total Confirmed:14075          0          127             0
# 4     Total Confirmed:39881          0          929             0
# ..                      ...        ...          ...           ...
# 166  Total Confirmed:115963          4          771           430
# 167       Total Confirmed:4          0            1             0
# 168    Total Confirmed:6948          0         1366             6
# 169  Total Confirmed:175729         47         2822          2726
# 170   Total Confirmed:67765         59         2185          1037
#
#              TotalRecovered   latitude   longitude
# 0     Total Recovered:81077  33.939110   67.709953
# 1    Total Recovered:130050  41.153332   20.168331
# 2    Total Recovered:101430  28.033886    1.659626
# 3     Total Recovered:13770  42.546245    1.601554
# 4     Total Recovered:34298 -11.202692   17.873887
# ..                      ...        ...         ...
# 166  Total Recovered:111189  41.377491   64.585262
# 167       Total Recovered:3 -15.376706  166.959158
# 168    Total Recovered:4141  15.552727   48.516388
# 169  Total Recovered:160215 -13.133897   27.849332
# 170   Total Recovered:45617 -19.015438   29.154857
#
# [171 rows x 10 columns]

# %%
def plotDot(point):
    folium.CircleMarker(location=[point.latitude, point.longitude],
                        radius=5,
                        weight=2,
                        popup = [point.Country,point.TotalConfirmed,point.TotalRecovered],
                        fill_color='#00FF00').add_to(m)

# %%
covid_final.apply(plotDot, axis = 1)

m.fit_bounds(m.get_bounds())

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d1ee392d6fbf45609d1a7f76b9d0537d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d1ee392d6fbf45609d1a7f76b9d0537d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_d1ee392d6fbf45609d1a7f76b9d0537d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_d1ee392d6fbf45609d1a7f76b9d0537d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# #### Generate base map for total deaths

# %%
m1 = folium.Map(tiles='StamenToner', min_zoom=2)

m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_fa79f8bb3a4e424e9ff391d558247239%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_fa79f8bb3a4e424e9ff391d558247239%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_fa79f8bb3a4e424e9ff391d558247239%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_fa79f8bb3a4e424e9ff391d558247239%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %%
deaths=covid_final['TotalDeaths'].astype(float)

# %%
lat=covid_final['latitude'].astype(float)

# %%
lon=covid_final['longitude'].astype(float)

# %% [markdown]
# #### Generate Heat map layer on the base map

# %%
m1.add_child(HeatMap(zip(lat,lon,deaths),radius=0))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_fa79f8bb3a4e424e9ff391d558247239%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_fa79f8bb3a4e424e9ff391d558247239%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_fa79f8bb3a4e424e9ff391d558247239%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_fa79f8bb3a4e424e9ff391d558247239%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...

# %% [markdown]
# #### Circular PopUps for information

# %%
def plotDot(point):
    folium.CircleMarker(location=[point.latitude, point.longitude],
                        radius=5,
                        weight=2,
                        popup = [point.Country,point.TotalDeaths],
                        fill_color='#000000').add_to(m1)

covid_final.apply(plotDot, axis = 1)

m1.fit_bounds(m1.get_bounds())

m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_fa79f8bb3a4e424e9ff391d558247239%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_fa79f8bb3a4e424e9ff391d558247239%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_fa79f8bb3a4e424e9ff391d558247239%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_fa79f8bb3a4e424e9ff391d558247239%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...
